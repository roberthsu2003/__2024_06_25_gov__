# %%
print("Hello! jupyter notebook!")
# Out:
# Hello! jupyter notebook!

# %%
width = float(input("請輸入矩形的寬:"))
height = float(input("請輸入矩形的高:"))
print("矩形的面積的面積是",width * height)
# Out:
# 矩形的面積的面積是 111295.62000000001
