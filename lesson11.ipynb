# %%
import numpy as np
np.linspace(-3,3)

# %%
array = np.linspace(-3,3,num=100)
array * 10

# %%
np.random.randint(50,size=100,high=101)
# Out:
# array([90, 62, 55, 97, 78, 94, 67, 93, 66, 91, 86, 65, 50, 51, 73, 72, 65,
#        58, 75, 69, 95, 61, 78, 93, 51, 89, 66, 91, 73, 69, 83, 94, 58, 68,
#        69, 69, 54, 90, 70, 94, 70, 64, 86, 54, 63, 85, 74, 82, 86, 53, 94,
#        88, 78, 95, 86, 96, 51, 50, 78, 50, 81, 91, 99, 97, 69, 55, 84, 67,
#        70, 58, 73, 93, 78, 77, 94, 93, 70, 94, 68, 94, 90, 81, 64, 99, 84,
#        72, 97, 96, 71, 95, 60, 57, 65, 72, 63, 56, 53, 50, 71, 54])

# %%
np.random.randint(50,size=(50,5),high=101)
# Out:
# array([[ 80,  63,  74,  62,  61],
#        [ 75,  60,  66,  63,  99],
#        [ 66,  94,  86,  93,  77],
#        [ 97,  57,  52,  84,  54],
#        [ 71,  52,  92,  86,  98],
#        [ 54,  50,  51,  67,  65],
#        [ 55,  82,  83,  52,  61],
#        [ 96,  50,  68,  56,  91],
#        [ 55,  67, 100,  98,  72],
#        [ 88,  67,  94,  55,  91],
#        [ 98,  61,  70,  67,  53],
#        [ 56,  61,  81,  60,  94],
#        [ 64,  80,  98,  67,  58],
#        [ 56,  58,  80,  91,  99],
#        [ 57,  76,  94,  52,  61],
#        [ 81,  76,  72,  70,  52],
#        [ 66,  96,  75,  57, 100],
#        [ 55,  56,  65,  90,  83],
#        [ 76,  65,  73, 100,  80],
#        [ 55,  50,  66,  57,  84],
#        [ 56,  68,  63,  79,  67],
#        [ 88,  89,  57,  96,  94],
#        [ 86,  63,  92,  51,  67],
#        [ 52,  67,  75,  59,  54],
#        [ 97,  82,  72,  59,  78],
#        [ 56,  65,  57,  67,  78],
#        [ 53,  63, 100,  97,  61],
#        [ 94,  92,  85,  76,  96],
#        [ 81,  63,  97,  93,  97],
#        [ 85,  85,  75,  66,  69],
#        [ 60,  61,  61,  86,  88],
#        [ 59, 100,  96,  94,  70],
#        [ 84,  90,  54,  60,  79],
#        [ 62,  98,  82,  73,  84],
#        [ 97,  50,  83,  75,  59],
#        [ 52,  50,  93,  70,  94],
#        [ 92,  58,  52,  85,  56],
#        [ 70,  75,  61,  68,  79],
#        [ 52,  54,  56,  68,  84],
#        [ 91,  87,  84,  52, 100],
#        [ 55,  70,  81,  58,  58],
#        [ 57,  89,  72,  75,  70],
#        [ 89,  76,  58,  82,  83],
#        [ 55,  94,  86,  93,  64],
#        [ 61,  62,  53,  52,  52],
#        [ 78,  81,  51,  85,  85],
#        [ 76,  82,  58,  53,  74],
#        [100,  81,  86,  65,  88],
#        [ 71,  67,  70,  52,  51],
#        [ 69,  73,  93,  93,  53]])
